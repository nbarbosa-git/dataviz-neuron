# %%
import pandas as pd


df = pd.read_csv('Lending_club_clean.csv', nrows=200000)

# %%
df.shape
# Out:
# (200000, 89)

# %%
df.to_csv('Lending_club_clean_200k.csv', index=False)

# %%
df.head()
# Out:
#    Unnamed: 0  acc_open_past_24mths addr_state  all_util  annual_inc  \
# 0           0                   3.0         OK      58.0     50000.0
# 1           1                  15.0         FL      51.0    196000.0
# 2           2                   5.0         NH      84.0     44000.0
# 3           3                   2.0         AL      90.0     65000.0
# 4           4                   3.0         WA       1.0     52000.0
#
#    annual_inc_joint application_type  avg_cur_bal  bc_open_to_buy  bc_util  \
# 0           5693.51       Individual       3869.0           384.0     23.2
# 1           5693.51       Individual      31468.0          7368.0     74.1
# 2          81000.00        Joint App       8397.0           632.0     66.7
# 3           5693.51       Individual      10685.0            63.0     98.1
# 4           5693.51       Individual      25099.0         30359.0      0.5
#
#    ...        term  tot_coll_amt  tot_hi_cred_lim  total_acc total_bc_limit  \
# ...
